# %%
# Importing Pandas an Numpy Libraries to use on manipulating our Data
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier, XGBRFClassifier
from sklearn.model_selection import cross_val_score

import sys
sys.path.append("../")

from scripts.pipeline_modeling import (
    run_train_pipeline, 
    get_pipeline,
    dvc_get_data)

import os
import mlflow

# %%
df = dvc_get_data(path='./data/AdSmartABdata.csv', 
                version='v2')               
df = df.drop(columns=['Unnamed: 0'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1243 entries, 0 to 1242
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   1243 non-null   object
#  1   hour         1243 non-null   int64
#  2   platform_os  1243 non-null   int64
#  3   browser      1243 non-null   object
#  4   day_of_week  1243 non-null   object
#  5   brand        1243 non-null   object
#  6   response     1243 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 68.1+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
model = LogisticRegression()
run_train_pipeline(model, x, y, 
                experiment_name='full cleaned dataset',
                run_name='logistic regression')
mlflow.end_run()
# Out:
# {'accuracy': 0.58, 'precision': 0.51, 'recall': 0.36, 'entropy': 0.68, 'true_pos': 160, 'true_neg': 57, 'false_pos': 54, 'false_neg': 102}
# {'experiment': -0.01, 'hour': 0.11, 'platform_os': 0.09, 'browser': -0.21, 'day_of_week': 0.02, 'brand': 0.24}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Run - logistic regression is logged to Experiment - full cleaned dataset

# %%
model = RandomForestClassifier()
run_train_pipeline(model, x, y, 
                experiment_name='full cleaned dataset',
                run_name=' random forest')
mlflow.end_run()
# Out:
# {'accuracy': 0.52, 'precision': 0.45, 'recall': 0.51, 'entropy': 0.86, 'true_pos': 113, 'true_neg': 81, 'false_pos': 101, 'false_neg': 78}
# {'experiment': 0.05, 'hour': 0.61, 'platform_os': 0.01, 'browser': 0.1, 'day_of_week': 0.21, 'brand': 0.03}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Run -  random forest is logged to Experiment - full cleaned dataset

# %%
model = RandomForestClassifier(max_depth=20)
run_train_pipeline(model, x, y, 
                experiment_name='full cleaned dataset',
                run_name='depth 20 random forest')
mlflow.end_run()
# Out:
# {'accuracy': 0.54, 'precision': 0.47, 'recall': 0.53, 'entropy': 0.87, 'true_pos': 119, 'true_neg': 84, 'false_pos': 95, 'false_neg': 75}
# {'experiment': 0.05, 'hour': 0.59, 'platform_os': 0.01, 'browser': 0.11, 'day_of_week': 0.22, 'brand': 0.03}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Run - depth 20 random forest is logged to Experiment - full cleaned dataset

# %% [markdown]
# # browser_chrome_mobile dataset

# %%
df = dvc_get_data(path='./data/browser_chrome_mobile.csv', 
                version='v2')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   695 non-null    int64
#  1   experiment   695 non-null    object
#  2   hour         695 non-null    int64
#  3   platform_os  695 non-null    int64
#  4   browser      695 non-null    object
#  5   day_of_week  695 non-null    object
#  6   brand        695 non-null    object
#  7   response     695 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 43.6+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
mlflow.end_run()
model = LogisticRegression()
run_train_pipeline(model, x, y, 
                experiment_name='browser_chrome_mobile dataset',
                run_name='logistic regression')
# Out:
# {'accuracy': 0.48, 'precision': 0.36, 'recall': 0.23, 'entropy': 0.72, 'true_pos': 79, 'true_neg': 21, 'false_pos': 38, 'false_neg': 71}
# {'Unnamed: 0': 0.16, 'experiment': -0.11, 'hour': 0.09, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.14, 'brand': 0.22}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Run - logistic regression is logged to Experiment - browser_chrome_mobile dataset
# {'accuracy': 0.48,
#  'precision': 0.36,
#  'recall': 0.23,
#  'entropy': 0.72,
#  'true_pos': 79,
#  'true_neg': 21,
#  'false_pos': 38,
#  'false_neg': 71}

# %%
mlflow.end_run()
model = RandomForestClassifier()
run_train_pipeline(model, x, y, 
                experiment_name='browser_chrome_mobile dataset',
                run_name='random forest')
# Out:
# {'accuracy': 0.52, 'precision': 0.44, 'recall': 0.39, 'entropy': 0.84, 'true_pos': 72, 'true_neg': 36, 'false_pos': 45, 'false_neg': 56}
# {'Unnamed: 0': 0.58, 'experiment': 0.02, 'hour': 0.28, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.11, 'brand': 0.02}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Run - random forest is logged to Experiment - browser_chrome_mobile dataset
# {'accuracy': 0.52,
#  'precision': 0.44,
#  'recall': 0.39,
#  'entropy': 0.84,
#  'true_pos': 72,
#  'true_neg': 36,
#  'false_pos': 45,
#  'false_neg': 56}

# %% [markdown]
# # XGBoost

# %%
df = dvc_get_data(path='./data/cleaned_data.csv', 
                version='v1')
df = df.drop(columns=['Unnamed: 0'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1243 entries, 0 to 1242
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   1243 non-null   object
#  1   hour         1243 non-null   int64
#  2   platform_os  1243 non-null   int64
#  3   browser      1243 non-null   object
#  4   day_of_week  1243 non-null   object
#  5   brand        1243 non-null   object
#  6   response     1243 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 68.1+ KB

# %%
x = df.drop(columns=['response'])
y = df['response'].values

# %%
mlflow.end_run()
model = XGBClassifier()
run_train_pipeline(model, x, y, 
                experiment_name='cleaned dataset',
                run_name=' XGBoost Classifier')
# Out:
# {'accuracy': 0.54, 'precision': 0.46, 'recall': 0.52, 'entropy': 0.86, 'true_pos': 119, 'true_neg': 82, 'false_pos': 95, 'false_neg': 77}
# {'experiment': 0.22, 'hour': 0.18, 'platform_os': 0.1, 'browser': 0.15, 'day_of_week': 0.18, 'brand': 0.19}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Run -  XGBoost Classifier is logged to Experiment - cleaned dataset
# {'accuracy': 0.54,
#  'precision': 0.46,
#  'recall': 0.52,
#  'entropy': 0.86,
#  'true_pos': 119,
#  'true_neg': 82,
#  'false_pos': 95,
#  'false_neg': 77}

# %%
mlflow.end_run()
model = XGBRFClassifier()
run_train_pipeline(model, x, y, 
                experiment_name='cleaned dataset',
                run_name='XGBoost random forest Classifier')
# Out:
# {'accuracy': 0.56, 'precision': 0.48, 'recall': 0.37, 'entropy': 0.68, 'true_pos': 150, 'true_neg': 59, 'false_pos': 64, 'false_neg': 100}
# {'experiment': 0.12, 'hour': 0.2, 'platform_os': 0.18, 'browser': 0.15, 'day_of_week': 0.16, 'brand': 0.18}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Run - XGBoost random forest Classifier is logged to Experiment - cleaned dataset
# {'accuracy': 0.56,
#  'precision': 0.48,
#  'recall': 0.37,
#  'entropy': 0.68,
#  'true_pos': 150,
#  'true_neg': 59,
#  'false_pos': 64,
#  'false_neg': 100}
